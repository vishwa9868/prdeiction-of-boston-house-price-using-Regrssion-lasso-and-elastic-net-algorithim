# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\Vishwanath\anaconda3\pkgs\scikit-learn-1.0.2-py39hf11a4ad_1\Lib\site-packages\sklearn\datasets\data\boston_house_prices.csv")

# %%
df
# Out:
#          506  13 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0       CRIM  ZN      INDUS       CHAS        NOX         RM        AGE
# 1    0.00632  18       2.31          0      0.538      6.575       65.2
# 2    0.02731   0       7.07          0      0.469      6.421       78.9
# 3    0.02729   0       7.07          0      0.469      7.185       61.1
# 4    0.03237   0       2.18          0      0.458      6.998       45.8
# ..       ...  ..        ...        ...        ...        ...        ...
# 502  0.06263   0      11.93          0      0.573      6.593       69.1
# 503  0.04527   0      11.93          0      0.573       6.12       76.7
# 504  0.06076   0      11.93          0      0.573      6.976         91
# 505  0.10959   0      11.93          0      0.573      6.794       89.3
# 506  0.04741   0      11.93          0      0.573       6.03       80.8
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...

# %%
from sklearn.datasets import load_boston

# %%
boston=load_boston()
# Out:
# C:\Users\Vishwanath\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(boston.data)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
print(boston.target)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
##Lets prepare the data Frame

# %%
dataset=pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
dataset["Price"]=boston.target

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
## check the missing values
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
## EDA
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
sns.set(rc={"figure.figsize" :(10,8)})
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(dataset["AGE"],dataset["Price"])
plt.xlabel("age of the pesons")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset["CRIM"],dataset["Price"])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset["RM"],dataset["Price"])
plt.xlabel("Rooms")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.regplot(x="RM",y="Price",data=dataset)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='Price'>

# %%
sns.regplot(x="CRIM",y="Price",data=dataset)
# Out:
# <AxesSubplot:xlabel='CRIM', ylabel='Price'>

# %%
sns.boxplot(dataset["Price"])
# Out:
# C:\Users\Vishwanath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
sns.boxplot(dataset["CRIM"])
# Out:
# C:\Users\Vishwanath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CRIM'>

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
## independent and dependent features
X= dataset.iloc[:,:-1]
Y=dataset.iloc[:,-1]

# %%
X.shape
# Out:
# (506, 13)

# %%
Y.shape
# Out:
# (506,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.25,random_state=10)

# %%
X_train.head()
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 167   1.80028   0.0  19.58   0.0  0.605  5.877  79.2  2.4259   5.0  403.0
# 318   0.40202   0.0   9.90   0.0  0.544  6.382  67.2  3.5325   4.0  304.0
# 99    0.06860   0.0   2.89   0.0  0.445  7.416  62.5  3.4952   2.0  276.0
# 307   0.04932  33.0   2.18   0.0  0.472  6.849  70.3  3.1827   7.0  222.0
# 404  41.52920   0.0  18.10   0.0  0.693  5.531  85.4  1.6074  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 167     14.7  227.61  12.14
# 318     18.4  395.21  10.36
# 99      18.0  396.90   6.19
# 307     18.4  396.90   7.53
# 404     20.2  329.46  27.38

# %%
Y_train.head()
# Out:
# 167    23.8
# 318    23.1
# 99     33.2
# 307    28.2
# 404     8.5
# Name: Price, dtype: float64

# %%
## Standardize the datasets
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.23129049, -0.48214334,  1.15722245, ..., -1.78565054,
#         -1.31262649, -0.12068074],
#        [-0.38232604, -0.48214334, -0.2326932 , ..., -0.06432123,
#          0.43624006, -0.37121508],
#        [-0.418341  , -0.48214334, -1.23923336, ..., -0.25041088,
#          0.45387482, -0.95814105],
#        ...,
#        [-0.16882547, -0.48214334,  0.94471469, ...,  0.77308222,
#          0.18079703,  0.04821882],
#        [-0.40749396, -0.48214334,  2.02879146, ...,  0.26133567,
#          0.32990981,  0.25512078],
#        [-0.34348321,  0.34940308, -1.08416012, ..., -2.57653157,
#          0.40691838, -0.35854762]])

# %%
X_test
# Out:
# array([[-0.41983271,  0.88990826, -1.34117965, ..., -0.06432123,
#          0.41693575, -0.57248706],
#        [-0.42338863,  2.01249593, -1.2334899 , ..., -1.36694881,
#          0.4170401 , -1.12141062],
#        [-0.42187963,  2.84404235, -1.17031192, ..., -1.13433674,
#          0.45387482, -1.17208049],
#        ...,
#        [-0.35317339, -0.48214334, -0.48540514, ...,  1.14526153,
#          0.24497083,  0.25512078],
#        [-0.41583717, -0.48214334, -1.07267322, ..., -0.90172467,
#          0.43926615, -0.5570046 ],
#        [ 0.37002059, -0.48214334,  0.94471469, ...,  0.77308222,
#         -2.67832848,  1.19955081]])

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
Linear_reg=LinearRegression()

# %%
Linear_reg
# Out:
# LinearRegression()

# %%
Linear_reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
## price the cooefficient and the intercept
print(Linear_reg.coef_)
# Out:
# [-1.16537843  1.38465289 -0.11434012  0.30184283 -1.80888677  2.34171166
#   0.32381052 -3.12165806  2.61116292 -2.10444862 -1.80820193  1.19593811
#  -3.81445728]

# %%
print(Linear_reg.intercept_)
# Out:
# 21.93377308707127

# %%
# prediction for test data
Linear_reg_pred=Linear_reg.predict(X_test)

# %%
Linear_reg_pred
# Out:
# array([31.11439635, 31.82060232, 30.55620556, 22.44042081, 18.80398782,
#        16.27625322, 36.13534369, 14.62463338, 24.56196194, 37.27961695,
#        21.29108382, 30.61258241, 27.94888799, 33.80697059, 33.25072336,
#        40.77177784, 24.3173198 , 23.29773241, 25.50732006, 21.08959787,
#        32.79810915, 17.7713081 , 25.36693209, 25.03811059, 32.51925813,
#        20.4761305 , 19.69609206, 16.93696274, 38.25660623,  0.70152499,
#        32.34837791, 32.21000333, 25.78226319, 23.95722044, 20.51116476,
#        19.53727258,  3.87253095, 34.74724529, 26.92200788, 27.63770031,
#        34.47281616, 29.80511271, 18.34867051, 31.37976427, 18.14935849,
#        28.22386149, 19.25418441, 21.71490395, 38.26297011, 16.44688057,
#        24.60894426, 19.48346848, 24.49571194, 34.48915635, 26.66802508,
#        34.83940131, 20.91913534, 19.60460332, 18.52442576, 25.00178799,
#        19.86388846, 23.46800342, 39.56482623, 42.95337289, 30.34352231,
# ...

# %%
###assumptions
plt.scatter(Y_test,Linear_reg_pred)
plt.xlabel("Test Truth Data")
plt.ylabel("Test Predicted Data")
# Out:
# Text(0, 0.5, 'Test Predicted Data')

# %%
##Residuals
Linear_Residuals=Y_test-Linear_reg_pred

# %%
Linear_Residuals
# Out:
# 305   -2.714396
# 193   -0.720602
# 65    -7.056206
# 349    4.159579
# 151    0.796012
#          ...
# 493    0.871902
# 142   -0.252837
# 26     0.407970
# 173   -5.651556
# 428   -2.283331
# Name: Price, Length: 127, dtype: float64

# %%
sns.displot(Linear_Residuals,kind="kde")

# %%
##scatter plot with prdiction and residuals
## uniform distribution
plt.scatter(x=Linear_reg_pred,y=Linear_Residuals)
plt.xlabel('Prediction')
plt.ylabel('Residulas')
# Out:
# Text(0, 0.5, 'Residulas')

# %%
## performance metrics

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print('MSE of the linear regression model is {}'.format(mean_squared_error(Y_test,Linear_reg_pred)))
print('MAE of the linear regression model is {}'. format(mean_absolute_error(Y_test,Linear_reg_pred)))
print('RMSE of the linear regression model is {}'.format(np.sqrt(mean_squared_error(Y_test,Linear_reg_pred))))
# Out:
# MSE of the linear regression model is 32.44253669600672
# MAE of the linear regression model is 3.8573009079955094
# RMSE of the linear regression model is 5.69583503061726

# %%
## squared and adjusted R square

# %%
lfrom sklearn.metrics import r2_score
Linear_R2_square = r2_score(Y_test,Linear_reg_pred)
print('The Linear Regression has a accuracy of {}%'.format(Linear_R2_square*100))
# Out:
# The Linear Regression has a accuracy of 67.45585065949405%

# %%
# R2 and adjusted R2
Ridge_R2_Square= r2_score (Y_test,Ridge_reg_pred)
Ridge_R2_Square
print('Ridge regression has the accuracy of {}'.format(round(Ridge_R2_Square*100,2)))
Ridge_Adjusted_R2_Square=1-(1-Ridge_R2 Square)*(len(Y_test)-1)/(len(Y_test)-X_test.shape[1]-1)
print("Ridge Adjusted R Square accuracy is {}%.".format(round(Ridge_Adjusted_R2_Square*100,3)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9272\857177810.py in <module>
#       1 # R2 and adjusted R2
# ----> 2 Ridge_R2_Square=r2_score(Y_test,Ridge_reg_pred)
#       3 Ridge_R2_Square
#       4 print('Ridge regression has the accuracy of ()%'.format(round(Ridge_R2_Square*100,2)))
#       5 Ridge_Adjusted_R2_Square=1-(1-Ridge_r2_Square)*(len(Y_test)-1)/(len(Y_test)-X_test.shape[1]-1)
#
# NameError: name 'Ridge_reg_pred' is not defined

# %% [markdown]
# # Laso Regression

# %%
from sklearn.linear_model import Lasso

# %%
Lasso_reg=Lasso()
Lasso_reg
# Out:
# Lasso()

# %%
Lasso_reg.fit(X_train,Y_train)
# Out:
# Lasso()

# %%
##printing coeffecient and Intercept
print("1.co=efficient of independent Feature is {}".format(Lasso_reg.coef_))
print("2. Independent of best fit plane is {}".format(Lasso_reg.intercept_))
# Out:
# 1.co=efficient of independent Feature is [-0.08918739  0.         -0.          0.         -0.          2.44512568
#  -0.         -0.         -0.         -0.         -1.20901738  0.5447417
#  -3.47423462]
# 2. Independent of best fit plane is 21.933773087071266

# %%
Lasso_reg_pred=Lasso_reg.predict(X_test)
Lasso_reg_pred
# Out:
# array([25.59213911, 29.74593695, 27.79963149, 27.506445  , 20.81529941,
#        18.63838437, 34.2585318 , 15.85546278, 20.61997497, 34.14996646,
#        19.84537557, 26.60295879, 23.97294821, 29.83985567, 29.1413883 ,
#        36.56749013, 26.12523576, 19.75360042, 23.85180384, 22.44495779,
#        30.80737188, 18.75532637, 23.83826155, 25.57515861, 32.38952347,
#        21.44871512, 20.79352745, 19.09775385, 34.1178964 ,  2.6321944 ,
#        30.58072839, 29.28298041, 26.76024494, 25.12933502, 19.30009695,
#        19.63255285,  7.85045145, 29.72929697, 25.24505887, 25.51785354,
#        32.41658086, 26.82699594, 18.05133697, 29.25387628, 18.90338802,
#        27.21018899, 20.39644552, 20.92886277, 34.44819423, 17.99945633,
#        23.55632903, 18.66869183, 22.41738327, 32.83237713, 25.97730002,
#        30.44087256, 20.40021358, 20.85628823, 17.51370785, 24.7494932 ,
#        21.33979623, 22.80214934, 36.79328969, 38.08568666, 28.09577083,
# ...

# %%
#Linear Relation
plt.scatter(x=Y_test, y=Lasso_reg_pred)
plt.xlabel('Truth data')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
## Residulas relation
Lasso_Residual_reg=Y_test-Lasso_reg_pred
Lasso_Residual_reg
# Out:
# 305    2.807861
# 193    1.354063
# 65    -4.299631
# 349   -0.906445
# 151   -1.215299
#          ...
# 493    1.461999
# 142   -1.087388
# 26    -1.624576
# 173   -2.232772
# 428   -4.123093
# Name: Price, Length: 127, dtype: float64

# %%
sns.displot(x=Lasso_Residual_reg,kind='kde')

# %%
## uniform distribution
plt.scatter(x=Lasso_reg_pred,y=Lasso_Residual_reg)
plt.xlabel("predicted")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %%
# MSE, MAE, RMSE
print("Mean squared error is {}".format(round(mean_squared_error(Y_test,Lasso_reg_pred),2)))
print("Mean absolute error is {}".format(round(mean_absolute_error(Y_test,Lasso_reg_pred),2)))
print("Root Mean Squared Error is {}",format(round(np.sqrt(mean_squared_error(Y_test,Lasso_reg_pred)),2)))
# Out:
# Mean squared error is 38.76
# Mean absolute error is 4.29
# Root Mean Squared Error is {} 6.23

# %%
## R squared and Adjusted R square
from sklearn.metrics import r2_score
Lasso_R2_square= r2_score(Y_test,Lasso_reg_pred)
print("Lasso Regreesion model gas {}% accuracy".format(round(Lasso_R2_square*100,3)))

Lasso_Adjusted_R2_square=1-(1-Lasso_R2_square)*(len(Y_test)-1)/(len(Y_test)-X_test.shape[1]-1)
print("Lasso Adjusted R square accuracy is {}%".format(round(Lasso_Adjusted_R2_square*100,2)))
# Out:
# Lasso Regreesion model gas 61.123% accuracy
# Lasso Adjusted R square accuracy is 56.65%

# %% [markdown]
# # Elastic Regression

# %%
from sklearn.linear_model import ElasticNet
Elasticnet_reg=ElasticNet()
Elasticnet_reg
# Out:
# ElasticNet()

# %%
Elasticnet_reg.fit(X_train,Y_train)
# Out:
# ElasticNet()

# %%
## printing Coefficient and intercepts
print("1.Co=efficient of independent Feature is {}".format(Elasticnet_reg.coef_))
print("2.Intercept of best fit plane is {}". format(Elasticnet_reg.intercept_))
# Out:
# 1.Co=efficient of independent Feature is [-0.45663049  0.26940967 -0.29777128  0.16828    -0.19430197  2.14987551
#  -0.         -0.         -0.         -0.3730676  -1.12962405  0.63310369
#  -2.24076091]
# 2.Intercept of best fit plane is 21.933773087071266

# %%
Elasticnet_reg_pred=Elasticnet_reg.predict(X_test)
Elasticnet_reg_pred
# Out:
# array([26.06988862, 29.65805573, 27.94942515, 27.30449071, 20.17567008,
#        17.62790133, 31.16625719, 16.54303242, 22.59384483, 32.15941795,
#        20.44598672, 26.9975995 , 24.38422141, 29.02142124, 29.24317891,
#        34.9094532 , 25.28785724, 21.18326856, 24.05718383, 22.49444017,
#        28.45158376, 18.18741859, 23.42644129, 24.9224316 , 31.20278952,
#        21.90347184, 22.37116882, 18.22092748, 33.5410405 ,  5.17023047,
#        30.97208096, 28.22432152, 27.10800387, 24.94923235, 19.16030161,
#        20.15097055,  9.75619312, 29.53126135, 24.40611997, 25.38620771,
#        30.71339994, 26.23365452, 17.89315025, 29.12443818, 20.7708996 ,
#        27.16149631, 19.32098961, 19.54697173, 33.23006282, 19.21335738,
#        22.89312035, 18.51383145, 22.79878751, 31.36107372, 24.98132301,
#        29.95296258, 20.76990169, 19.59830859, 18.22124381, 22.65616887,
#        20.65584528, 22.70537012, 34.3022025 , 36.15465482, 27.23756743,
# ...

# %%
# Linear Relation
plt.scatter(x=Y_test,y=Elasticnet_reg_pred)
plt.xlabel('True_value')
plt.ylabel('prediction')
# Out:
# Text(0, 0.5, 'prediction')

# %%
## Residuals Relation
Residual_Elasticnet=Y_test-Elasticnet_reg_pred
Residual_Elasticnet
# Out:
# 305    2.330111
# 193    1.441944
# 65    -4.449425
# 349   -0.704491
# 151   -0.575670
#          ...
# 493    1.264320
# 142   -3.482284
# 26    -2.615727
# 173   -2.079135
# 428   -4.121945
# Name: Price, Length: 127, dtype: float64

# %%
sns.displot(x=Residual_Elasticnet,kind='kde')

# %%
## uniform Relation
plt.scatter(x=Elasticnet_reg_pred,y=Residual_Elasticnet)
plt.xlabel('prediction')
plt.ylabel("Residual")
# Out:
# Text(0, 0.5, 'Residual')

# %%
## MSE,MAE,RMSE
print("Mean squared error is {}".format(round(mean_squared_error(Y_test,Elasticnet_reg_pred),2)))
print("Mean absolute error is {}".format(round(mean_absolute_error(Y_test,Elasticnet_reg_pred),2)))
print("Root Mean squared error is {}".format(round(np.sqrt(mean_squared_error(Y_test,Elasticnet_reg_pred)),2)))
# Out:
# Mean squared error is 43.2
# Mean absolute error is 4.49
# Root Mean squared error is 6.57

# %%
## R square and adjusted R square
from sklearn.metrics import r2_score
Elasticnet_R2_square=r2_score(Y_test,Elasticnet_reg_pred)
print("Elaasticnet Regression model has {}% accuracy".format(round(Elasticnet_R2_square*100,3)))

Elasticnet_Adjusted_R2_square=1-(1-Elasticnet_R2_square)*(len(Y_test)-1)/(len(Y_test)-X_test.shape[1]-1)
print('Adjusted R square accuracy is {}%'.format(round(Elasticnet_Adjusted_R2_square*100,3)))
# Out:
# Elaasticnet Regression model has 56.665% accuracy
# Adjusted R square accuracy is 51.68%
